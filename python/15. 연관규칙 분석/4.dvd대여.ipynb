# %%
import pandas as pd
df=pd.read_csv('c:/data/basket/dvdtrans.csv')
df.head()
# Out:
#    ID           Item
# 0   1    Sixth Sense
# 1   1          LOTR1
# 2   1  Harry Potter1
# 3   1     Green Mile
# 4   1          LOTR2

# %%
#2차원 리스트로 읽기
items = []
for row in range(0, df.shape[0]):
    items.append([df.iloc[row,0],str(df.iloc[row,1])])
    
print(items)
# Out:
# [[1, 'Sixth Sense'], [1, 'LOTR1'], [1, 'Harry Potter1'], [1, 'Green Mile'], [1, 'LOTR2'], [2, 'Gladiator'], [2, 'Patriot'], [2, 'Braveheart'], [3, 'LOTR1'], [3, 'LOTR2'], [4, 'Gladiator'], [4, 'Patriot'], [4, 'Sixth Sense'], [5, 'Gladiator'], [5, 'Patriot'], [5, 'Sixth Sense'], [6, 'Gladiator'], [6, 'Patriot'], [6, 'Sixth Sense'], [7, 'Harry Potter1'], [7, 'Harry Potter2'], [8, 'Gladiator'], [8, 'Patriot'], [9, 'Gladiator'], [9, 'Patriot'], [9, 'Sixth Sense'], [10, 'Sixth Sense'], [10, 'LOTR'], [10, 'Gladiator'], [10, 'Green Mile']]

# %%
result=[]
for i in range(1,11):
    row=[]
    for item in items:
        if item[0]==i:
            row.append(item[1])
        result.append(row)
        
print(result)
# Out:
# [['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['Sixth Sense', 'LOTR1', 'Harry Potter1', 'Green Mile', 'LOTR2'], ['S
TR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['LOTR1', 'LOTR2'], ['Gladiator', 'Patriot', 'Sixth Sense'], ['Gladiator', 'Patriot', 'Sixth Sense'], ['Gladiator', 'Patriot', 'Sixth Sense'], ['Gladiator', 'Patriot', 'Sixth Sense'], ['Gladiator', 'Patriot', 'Sixth Sense'], ['Gladiator',  ...

# %%
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
te = TransactionEncoder()
t_arr = te.fit(result).transform(result)
print(te.columns_)
print(t_arr)
# Out:
# ['Braveheart', 'Gladiator', 'Green Mile', 'Harry Potter1', 'Harry Potter2', 'LOTR', 'LOTR1', 'LOTR2', 'Patriot', 'Sixth Sense']
# [[False False  True ...  True False  True]
#  [False False  True ...  True False  True]
#  [False False  True ...  True False  True]
#  ...
#  [False  True  True ... False False  True]
#  [False  True  True ... False False  True]
#  [False  True  True ... False False  True]]

# %%
df2 = pd.DataFrame(t_arr, columns = te.columns_)
df2
# Out:
#      Braveheart  Gladiator  Green Mile  Harry Potter1  Harry Potter2   LOTR  \
# 0         False      False        True           True          False  False
# 1         False      False        True           True          False  False
# 2         False      False        True           True          False  False
# 3         False      False        True           True          False  False
# 4         False      False        True           True          False  False
# ..          ...        ...         ...            ...            ...    ...
# 295       False       True        True          False          False   True
# 296       False       True        True          False          False   True
# 297       False       True        True          False          False   True
# 298       False       True        True          False          False   True
# 299       False       True        True          False          False   True
#
#      LOTR1  LOTR2  Patriot  Sixth Sense
# 0     True   True    False         True
# 1     True   True    False         True
# 2     True   True    False         True
# 3     True   True    False         True
# 4     True   True    False         True
# ..     ...    ...      ...          ...
# 295  False  False    False         True
# 296  False  False    False         True
# 297  False  False    False         True
# 298  False  False    False         True
# 299  False  False    False         True
#
# [300 rows x 10 columns]

# %%
from mlxtend.frequent_patterns import apriori
frequent = apriori(df2, min_support=0.2, use_colnames=True)
frequent
# Out:
#     support                           itemsets
# 0       0.7                        (Gladiator)
# 1       0.2                       (Green Mile)
# 2       0.2                    (Harry Potter1)
# 3       0.2                            (LOTR1)
# 4       0.2                            (LOTR2)
# 5       0.6                          (Patriot)
# 6       0.6                      (Sixth Sense)
# 7       0.6               (Patriot, Gladiator)
# 8       0.5           (Gladiator, Sixth Sense)
# 9       0.2          (Green Mile, Sixth Sense)
# 10      0.2                     (LOTR2, LOTR1)
# 11      0.4             (Patriot, Sixth Sense)
# 12      0.4  (Patriot, Gladiator, Sixth Sense)

# %%
#신뢰도 0.1 기준
from mlxtend.frequent_patterns import association_rules
rules=association_rules(frequent, metric='confidence', min_threshold=0.1)
rules
# Out:
#                  antecedents               consequents  antecedent support  \
# 0                  (Patriot)               (Gladiator)                 0.6
# 1                (Gladiator)                 (Patriot)                 0.7
# 2                (Gladiator)             (Sixth Sense)                 0.7
# 3              (Sixth Sense)               (Gladiator)                 0.6
# 4               (Green Mile)             (Sixth Sense)                 0.2
# 5              (Sixth Sense)              (Green Mile)                 0.6
# 6                    (LOTR2)                   (LOTR1)                 0.2
# 7                    (LOTR1)                   (LOTR2)                 0.2
# 8                  (Patriot)             (Sixth Sense)                 0.6
# 9              (Sixth Sense)                 (Patriot)                 0.6
# 10      (Patriot, Gladiator)             (Sixth Sense)                 0.6
# 11    (Patriot, Sixth Sense)               (Gladiator)                 0.4
# 12  (Gladiator, Sixth Sense)                 (Patriot)                 0.5
# 13                 (Patriot)  (Gladiator, Sixth Sense)                 0.6
# 14               (Gladiator)    (Patriot, Sixth Sense)                 0.7
# 15             (Sixth Sense)      (Patriot, Gladiator)                 0.6
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.7      0.6    1.000000  1.428571      0.18         inf
# 1                  0.6      0.6    0.857143  1.428571      0.18         2.8
# 2                  0.6      0.5    0.714286  1.190476      0.08         1.4
# 3                  0.7      0.5    0.833333  1.190476      0.08         1.8
# 4                  0.6      0.2    1.000000  1.666667      0.08         inf
# 5                  0.2      0.2    0.333333  1.666667      0.08         1.2
# 6                  0.2      0.2    1.000000  5.000000      0.16         inf
# 7                  0.2      0.2    1.000000  5.000000      0.16         inf
# 8                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 9                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 10                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 11                 0.7      0.4    1.000000  1.428571      0.12         inf
# 12                 0.6      0.4    0.800000  1.333333      0.10         2.0
# 13                 0.5      0.4    0.666667  1.333333      0.10         1.5
# 14                 0.4      0.4    0.571429  1.428571      0.12         1.4
# 15                 0.6      0.4    0.666667  1.111111      0.04         1.2
#
#     zhangs_metric
# 0        0.750000
# 1        1.000000
# 2        0.533333
# 3        0.400000
# 4        0.500000
# 5        1.000000
# 6        1.000000
# 7        1.000000
# 8        0.250000
# 9        0.250000
# 10       0.250000
# 11       0.500000
# 12       0.500000
# 13       0.625000
# 14       1.000000
# 15       0.250000

# %%
from matplotlib import font_manager, rc
#한글 처리를 위해 폰트 설정
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import networkx as nx
import matplotlib.pyplot as plt
ga=nx.from_pandas_edgelist(rules,source='antecedents',target='consequents')
plt.figure(figsize=(15,8))
nx.draw(ga,with_labels=True,font_family=font_name,font_size=15)
